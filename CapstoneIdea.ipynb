# %% [markdown]
# # A recommendation system for food stalls aimed at students (based on student count and location of schools/ colleges in Mumbai, India)

# %% [markdown]
# ## Brief Introduction

# %% [markdown]
# ## Part 1: Description of problem

# %% [markdown]
# ### Mumbai, India is an extremely densely populated city (one of the most dense), with more than 18 million residents.
#
# ### Obviously it is tough to start a business here due to high real estate costs. So, an entrepreneur aiming at a student centric market (13 - 20 year old demographic) should know the best places to set up shop.
#
# ### A large population of Mumbai lies in this student demographic (more than 50 schools), and eating snack foods out is more popular and convenient than ever, hence we will find the best places in Mumbai to set up a food shop/ restaurant

# %% [markdown]
# ### Target audience:
# ### Entrepreneurs and small-scale businessmen/women interested in the food/ snacks industry, aiming at the student demographic

# %% [markdown]
#  #

# %% [markdown]
# ## Part 2: Data that is needed

# %% [markdown]
# ### 1. **We need a list of the most populated schools in Mumbai.** Their latitude and longitude will be calculated using geopy Nominatim.
#
# This data can be found on Wikipedia, as well as the school websites.
#
# For instance: https://en.wikipedia.org/wiki/List_of_educational_institutions_in_Mumbai
#
# ### 2. **Then we can use the FourSquare API to find the number of eateries in a 1km radius around each school.** The API will provide us with Postal Code, Neighborhood, Venue, Venue Summary and Venue Category.
#
# Foursquare is a local search-and-discovery service mobile app which provides search results for its users (Wikipedia). It has more than 60 million users.
#
# ### 3. Processing the Retrieved data and creating a structured DataFrame for all the venues, grouped by schools.
#
# ### 4. Selecting relevant venues (food related only).
#
# ### **The schools with highest ratio of `(no. of students)/(no. of eateries)` would be the best places to start a food stall/ restaurant.** (supply and demand)
#
# We can also create clusters of most highly student populated areas

# %% [markdown]
# ### Thank you for your time, I would greatly appreciate any feedback (sidjain1412@gmail.com)

# %% [markdown]
# **Data examples:**

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode("Lilavatibai podar santacruz Mumbai India").raw
lat = location['lat']
lon = location['lon']
print("Latitude: ", lat)
print("Longitutde: ", lon)
# Out:
# Latitude:  19.0810735
# Longitutde:  72.8371727

# %%
radius = 1000
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lat, 
    lon, 
    radius, 
    100)

# %%
import requests

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c7c2d8f6a60714c80d24d4e'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ce017cbdb125481d7a13ace-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '4ce017cbdb125481d7a13ace',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'distance': 184,
#         'formattedAddress': ['Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.081607436400976,
#           'lng': 72.83551217986849}],
#         'lat': 19.081607436400976,
#         'lng': 72.83551217986849,
#         'state': 'Mahārāshtra'},
#        'name': 'Gokul Icecreams',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cda8dc7b34e60fc88e64399-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '4cda8dc7b34e60fc88e64399',
#        'location': {'address': 'Kanu Desai Rd, Station Rd, Santacruz (W)',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 343,
#         'formattedAddress': ['Kanu Desai Rd, Station Rd, Santacruz (W)',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08070030358886,
#           'lng': 72.84041405733342}],
#         'lat': 19.08070030358886,
#         'lng': 72.84041405733342,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Sandwizzaa',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587e3f964a520d0a522e3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d108951735',
#          'name': "Women's Store",
#          'pluralName': "Women's Stores",
#          'primary': True,
#          'shortName': "Women's Store"}],
#        'id': '4b0587e3f964a520d0a522e3',
#        'location': {'address': 'Station Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 121,
#         'formattedAddress': ['Station Road',
#          'Mumbai 400 054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.080886712099723,
#           'lng': 72.83830996979094}],
#         'lat': 19.080886712099723,
#         'lng': 72.83830996979094,
#         'postalCode': '400 054',
#         'state': 'Mahārāshtra'},
#        'name': 'Seasons',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dfcac8462846d918b94de17-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'primary': True,
#          'shortName': 'Convenience Store'}],
#        'id': '4dfcac8462846d918b94de17',
#        'location': {'address': '97-B, Juhu Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Opposite SBI Bank',
#         'distance': 374,
#         'formattedAddress': ['97-B, Juhu Road (Opposite SBI Bank)',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08433809280489,
#           'lng': 72.83629790876921}],
#         'lat': 19.08433809280489,
#         'lng': 72.83629790876921,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Society Stores',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ce52b037f69b60c42ebb212-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'primary': True,
#          'shortName': 'Food Truck'}],
#        'id': '4ce52b037f69b60c42ebb212',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 327,
#         'formattedAddress': ['Mumbai 400054', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.078219890633292,
#           'lng': 72.83641120136797}],
#         'lat': 19.078219890633292,
#         'lng': 72.83641120136797,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Ram & Shyam',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50f7f3f1e4b050d90bf501c7-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'primary': True,
#          'shortName': 'Apparel'}],
#        'id': '50f7f3f1e4b050d90bf501c7',
#        'location': {'address': 'Santacruz',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Link Road',
#         'distance': 324,
#         'formattedAddress': ['Santacruz (Link Road)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.079782308329747,
#           'lng': 72.83440250081509}],
#         'lat': 19.079782308329747,
#         'lng': 72.83440250081509,
#         'state': 'Mahārāshtra'},
#        'name': 'Being Human Store',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4eb0f2b9e5fab9eba2522f36-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4eb0f2b9e5fab9eba2522f36',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Sujata Building, Opp. Santacruz Police',
#         'distance': 431,
#         'formattedAddress': ['Mumbai 400054', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.084431748305015,
#           'lng': 72.83512751367549}],
#         'lat': 19.084431748305015,
#         'lng': 72.83512751367549,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Three Wise Men',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '49768097'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fcd2a5ac2ee5182267c3fed-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111951735',
#          'name': 'Jewelry Store',
#          'pluralName': 'Jewelry Stores',
#          'primary': True,
#          'shortName': 'Jewelry'}],
#        'id': '4fcd2a5ac2ee5182267c3fed',
#        'location': {'address': 'Anand Commercial Centre',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'S V Road, Santacruz West',
#         'distance': 180,
#         'formattedAddress': ['Anand Commercial Centre (S V Road, Santacruz West)',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.082495443817308,
#           'lng': 72.83800669990914}],
#         'lat': 19.082495443817308,
#         'lng': 72.83800669990914,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Atrang Fashions',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '53782823'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53e0f513498ed30467e2012d-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '53e0f513498ed30467e2012d',
#        'location': {'address': 'savoy chambers, linking road extention',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'next to mini showroom',
#         'distance': 564,
#         'formattedAddress': ['savoy chambers, linking road extention (next to mini showroom)',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.085573692737334,
#           'lng': 72.83469121072112}],
#         'lat': 19.085573692737334,
#         'lng': 72.83469121072112,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Joss',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d50090f4015b1f7fa2c62cf-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4d50090f4015b1f7fa2c62cf',
#        'location': {'address': 'Willingdon Catholic Colony',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'S.V. Road',
#         'distance': 435,
#         'formattedAddress': ['Willingdon Catholic Colony (S.V. Road)',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.077201706270866,
#           'lng': 72.83774198415851}],
#         'lat': 19.077201706270866,
#         'lng': 72.83774198415851,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Nice Fast Food Corner',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c500f4c2ba0ef3b988849e8-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4c500f4c2ba0ef3b988849e8',
#        'location': {'address': 'Dunhill Corner, Santacruz East',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': '7th Golibar Rd., T.P.S-3',
#         'distance': 668,
#         'formattedAddress': ['Dunhill Corner, Santacruz East (7th Golibar Rd., T.P.S-3)',
#          'Mumbai India',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.077994253015287,
#           'lng': 72.84263076212586}],
#         'lat': 19.077994253015287,
#         'lng': 72.84263076212586,
#         'postalCode': 'India',
#         'state': 'Mahārāshtra'},
#        'name': 'K 11 Fitness Gym & Academy',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5275159f11d265069773cd85-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '5275159f11d265069773cd85',
#        'location': {'address': '15th Road, Red Chillies Building',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Ramakrishna Mission Road, South Avenue, Santacruz ',
#         'distance': 841,
#         'formattedAddress': ['15th Road, Red Chillies Building (Ramakrishna Mission Road, South Avenue, Santacruz )',
#          'Santacruz West 4000052',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.075523243262623,
#           'lng': 72.8317448378628}],
#         'lat': 19.075523243262623,
#         'lng': 72.8317448378628,
#         'postalCode': '4000052',
#         'state': 'Mahārāshtra'},
#        'name': 'Starbucks Coffee: A Tata Alliance',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d3192345c2db60c424cb96c-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d106951735',
#          'name': "Men's Store",
#          'pluralName': "Men's Stores",
#          'primary': True,
#          'shortName': "Men's Store"}],
#        'id': '4d3192345c2db60c424cb96c',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 299,
#         'formattedAddress': ['Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08036792508514,
#           'lng': 72.83443003448495}],
#         'lat': 19.08036792508514,
#         'lng': 72.83443003448495,
#         'state': 'Mahārāshtra'},
#        'name': 'Jack & Jones',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-597839cea8eb603d9bb36147-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'primary': True,
#          'shortName': 'Lounge'}],
#        'id': '597839cea8eb603d9bb36147',
#        'location': {'address': 'Ramee Emrald 2, Next to Bebe',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Linking Road',
#         'distance': 667,
#         'formattedAddress': ['Ramee Emrald 2, Next to Bebe (Linking Road)',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.07587218782422,
#           'lng': 72.83401688106666}],
#         'lat': 19.07587218782422,
#         'lng': 72.83401688106666,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Bombay Adda',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc00b55461576b0e3ba7932-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4bc00b55461576b0e3ba7932',
#        'location': {'address': 'Hasnabad Lane,',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Khar West',
#         'distance': 719,
#         'formattedAddress': ['Hasnabad Lane, (Khar West)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.075178900940426,
#           'lng': 72.83998310455414}],
#         'lat': 19.075178900940426,
#         'lng': 72.83998310455414,
#         'state': 'Mahārāshtra'},
#        'name': 'Willingdon Catholic Gymkhana',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fc08ad3e4b014a2d6544ddc-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'id': '4fc08ad3e4b014a2d6544ddc',
#        'location': {'address': 'G2, 3 North Avenue, Maker Maxity',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Bandra Kurla Complex',
#         'distance': 802,
#         'formattedAddress': ['G2, 3 North Avenue, Maker Maxity (Bandra Kurla Complex)',
#          'Mumbai 400051',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.07885768117065,
#           'lng': 72.82990923188731}],
#         'lat': 19.07885768117065,
#         'lng': 72.82990923188731,
#         'postalCode': '400051',
#         'state': 'Mahārāshtra'},
#        'name': 'Le Pain Quotidien',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587def964a520e5a422e3-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'primary': True,
#          'shortName': 'Furniture / Home'}],
#        'id': '4b0587def964a520e5a422e3',
#        'location': {'address': '60-A, Linking Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'near Arya Samaj',
#         'distance': 505,
#         'formattedAddress': ['60-A, Linking Road (near Arya Samaj)',
#          'Mumbai 400 054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.0772178986087,
#           'lng': 72.83462963552812}],
#         'lat': 19.0772178986087,
#         'lng': 72.83462963552812,
#         'postalCode': '400 054',
#         'state': 'Mahārāshtra'},
#        'name': 'Tresorie',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e12e72c45dde6c62de01900-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d104951735',
#          'name': 'Boutique',
#          'pluralName': 'Boutiques',
#          'primary': True,
#          'shortName': 'Boutique'}],
#        'id': '4e12e72c45dde6c62de01900',
#        'location': {'address': 'Linking road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 294,
#         'formattedAddress': ['Linking road', 'Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.080433470662683,
#           'lng': 72.83445798844427}],
#         'lat': 19.080433470662683,
#         'lng': 72.83445798844427,
#         'state': 'Mahārāshtra'},
#        'name': 'Veromoda',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d3869b0b9e5224bf8be5390-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '4d3869b0b9e5224bf8be5390',
#        'location': {'address': 'S.V. Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 373,
#         'formattedAddress': ['S.V. Road', 'Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.077763352263347,
#           'lng': 72.83774351577446}],
#         'lat': 19.077763352263347,
#         'lng': 72.83774351577446,
#         'state': 'Mahārāshtra'},
#        'name': 'Yoko Sizzlers',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ef9c70cbe7bb4784f9df80a-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'primary': True,
#          'shortName': 'Snacks'}],
#        'id': '4ef9c70cbe7bb4784f9df80a',
#        'location': {'address': 'Off Linking Road, Santacruz W',
#         'cc': 'IN',
#         'country': 'India',
#         'distance': 693,
#         'formattedAddress': ['Off Linking Road, Santacruz W', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.07531488640619,
#           'lng': 72.83466870246613}],
#         'lat': 19.07531488640619,
#         'lng': 72.83466870246613},
#        'name': 'Radhe Krishna Chat',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57a83648498e3e874a9f382d-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '57a83648498e3e874a9f382d',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 281,
#         'formattedAddress': ['Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.078608169160958,
#           'lng': 72.83777782612522}],
#         'lat': 19.078608169160958,
#         'lng': 72.83777782612522,
#         'state': 'Mahārāshtra'},
#        'name': 'Coffee By Di Bella',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d73a0a3946b6dcbcdc14e7a-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'id': '4d73a0a3946b6dcbcdc14e7a',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 875,
#         'formattedAddress': ['Mumbai 400049', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.084403012967847,
#           'lng': 72.8296315412298}],
#         'lat': 19.084403012967847,
#         'lng': 72.8296315412298,
#         'postalCode': '400049',
#         'state': 'Mahārāshtra'},
#        'name': 'Wai Yu Mun Ching',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587d6f964a520a3a322e3-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '4b0587d6f964a520a3a322e3',
#        'location': {'address': 'Swami Vivekananda Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 92,
#         'formattedAddress': ['Swami Vivekananda Road',
#          'Mumbai 400 054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08152253814692,
#           'lng': 72.83791135600347}],
#         'lat': 19.08152253814692,
#         'lng': 72.83791135600347,
#         'postalCode': '400 054',
#         'state': 'Mahārāshtra'},
#        'name': "Yoko's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4de4db53ae60e7f3ac276bc4-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4de4db53ae60e7f3ac276bc4',
#        'location': {'address': 'Santacruz - West',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 405,
#         'formattedAddress': ['Santacruz - West',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.082411186720574,
#           'lng': 72.8407586240743}],
#         'lat': 19.082411186720574,
#         'lng': 72.8407586240743,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Shabari Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-524da061498edf2777ff148b-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'primary': True,
#          'shortName': 'Apparel'}],
#        'id': '524da061498edf2777ff148b',
#        'location': {'address': 'Raheja Chamber, Linking Rd',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': '& Main Av. Crossing,santacruz (w)',
#         'distance': 521,
#         'formattedAddress': ['Raheja Chamber, Linking Rd (& Main Av. Crossing,santacruz (w))',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.0771284852764,
#           'lng': 72.83450356224128}],
#         'lat': 19.0771284852764,
#         'lng': 72.83450356224128,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'United Colors of Benetton',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dbbe6576e810768bf4fba84-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'primary': True,
#          'shortName': 'Juice Bar'}],
#        'id': '4dbbe6576e810768bf4fba84',
#        'location': {'address': '14A Ahimsa Marg, Opp. Mahavir Hospital',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Nr. Toyota Showroom',
#         'distance': 924,
#         'formattedAddress': ['14A Ahimsa Marg, Opp. Mahavir Hospital (Nr. Toyota Showroom)',
#          'Mumbai 400052',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.07413410709258,
#           'lng': 72.83235050804336}],
#         'lat': 19.07413410709258,
#         'lng': 72.83235050804336,
#         'postalCode': '400052',
#         'state': 'Mahārāshtra'},
#        'name': 'Fellas',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '71814444'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd13a33a8b3a593b583655f-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4bd13a33a8b3a593b583655f',
#        'location': {'address': 'Santacruz Avenue, Near Kotak Mahindra Bank.',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Linking Road',
#         'distance': 385,
#         'formattedAddress': ['Santacruz Avenue, Near Kotak Mahindra Bank. (Linking Road)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.07842882858914,
#           'lng': 72.83480374691828}],
#         'lat': 19.07842882858914,
#         'lng': 72.83480374691828,
#         'state': 'Mahārāshtra'},
#        'name': 'Powerhouse Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-514d6a9ee4b020b3a8bc2112-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'primary': True,
#          'shortName': 'Music Venue'}],
#        'id': '514d6a9ee4b020b3a8bc2112',
#        'location': {'address': 'Shankh Studio,Shivraj Heights,2nd Floor,14th road,Opp Bose Store',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Off linking road',
#         'distance': 874,
#         'formattedAddress': ['Shankh Studio,Shivraj Heights,2nd Floor,14th road,Opp Bose Store (Off linking road)',
#          'Mumbai 400050',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.073877370309003,
#           'lng': 72.83384360758069}],
#         'lat': 19.073877370309003,
#         'lng': 72.83384360758069,
#         'postalCode': '400050',
#         'state': 'Mahārāshtra'},
#        'name': 'Shankh Recording Studio',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b1cb1a8f964a520160924e3-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4b1cb1a8f964a520160924e3',
#        'location': {'address': 'Rna Classic',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Santacruz (West)',
#         'distance': 267,
#         'formattedAddress': ['Rna Classic (Santacruz (West))',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.07874382787301,
#           'lng': 72.83780638425937}],
#         'lat': 19.07874382787301,
#         'lng': 72.83780638425937,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Fatkong Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587e1f964a5206aa522e3-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'primary': True,
#          'shortName': 'Apparel'}],
#        'id': '4b0587e1f964a5206aa522e3',
#        'location': {'address': 'Ground Floor, Raheja Centre',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Santacruz West, Linking Road',
#         'distance': 478,
#         'formattedAddress': ['Ground Floor, Raheja Centre (Santacruz West, Linking Road)',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.076816968976672,
#           'lng': 72.83655720582995}],
#         'lat': 19.076816968976672,
#         'lng': 72.83655720582995,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Tommy Hilfiger',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b531d83f964a520508f27e3-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d129951735',
#          'name': 'Train Station',
#          'pluralName': 'Train Stations',
#          'primary': True,
#          'shortName': 'Train Station'}],
#        'id': '4b531d83f964a520508f27e3',
#        'location': {'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 520,
#         'formattedAddress': ['Mumbai 400054', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08110611964535,
#           'lng': 72.8421232792363}],
#         'lat': 19.08110611964535,
#         'lng': 72.8421232792363,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Santacruz Railway Station',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ca0a3cc542b224bb28107a0-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4ca0a3cc542b224bb28107a0',
#        'location': {'address': "SHOP NO. G-102, 'A' WING, ORCHID PRIDE BUILDING NEAR VODAFONE S.V. ROAD, SANTACRUZ (WEST),MUMBAI - 400054 PH.NO. 022-26003143",
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'SV Rd',
#         'distance': 555,
#         'formattedAddress': ["SHOP NO. G-102, 'A' WING, ORCHID PRIDE BUILDING NEAR VODAFONE S.V. ROAD, SANTACRUZ (WEST),MUMBAI - 400054 PH.NO. 022-26003143 (SV Rd)",
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.07610587436067,
#           'lng': 72.83772077741584}],
#         'lat': 19.07610587436067,
#         'lng': 72.83772077741584,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': "Domino's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4da41bb49935a0936e10d66f-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'primary': True,
#          'shortName': 'Snacks'}],
#        'id': '4da41bb49935a0936e10d66f',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'crossStreet': '16th Road khar (w)',
#         'distance': 878,
#         'formattedAddress': ['16th Road khar (w)', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.07562627781871,
#           'lng': 72.8311243836952}],
#         'lat': 19.07562627781871,
#         'lng': 72.8311243836952},
#        'name': 'Manju Dosa',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d9da0bac593a1cd46c06319-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4d9da0bac593a1cd46c06319',
#        'location': {'address': 'S. V. Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Santacruz',
#         'distance': 863,
#         'formattedAddress': ['S. V. Road (Santacruz)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08877286817361,
#           'lng': 72.83817676701563}],
#         'lat': 19.08877286817361,
#         'lng': 72.83817676701563,
#         'state': 'Mahārāshtra'},
#        'name': 'Cafe Coffee Day',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d2464c014f2b1f7d5cd6dbe-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4d2464c014f2b1f7d5cd6dbe',
#        'location': {'address': 'Juhu Tara Rd.',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 877,
#         'formattedAddress': ['Juhu Tara Rd.',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.084462,
#           'lng': 72.829646}],
#         'lat': 19.084462,
#         'lng': 72.829646,
#         'state': 'Mahārāshtra'},
#        'name': 'Cafe Coffee Day',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e310a5d18380c94aca6ec0d-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4e310a5d18380c94aca6ec0d',
#        'location': {'address': 'Opp post office, nehru road, santaceuz east',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 552,
#         'formattedAddress': ['Opp post office, nehru road, santaceuz east',
#          'Mumbai 400055',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.080892289035827,
#           'lng': 72.84242434751901}],
#         'lat': 19.080892289035827,
#         'lng': 72.84242434751901,
#         'postalCode': '400055',
#         'state': 'Mahārāshtra'},
#        'name': 'Gopal Krishna',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f86d39fe4b0bd6fe0bc3d8d-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '4f86d39fe4b0bd6fe0bc3d8d',
#        'location': {'address': 'Santacruz West',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 131,
#         'formattedAddress': ['Santacruz West',
#          'Mumbai 400054',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.0819054841995,
#           'lng': 72.8362816572189}],
#         'lat': 19.0819054841995,
#         'lng': 72.8362816572189,
#         'postalCode': '400054',
#         'state': 'Mahārāshtra'},
#        'name': 'Bakers & More',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c8e58381992a1cd66f7dcfb-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4c8e58381992a1cd66f7dcfb',
#        'location': {'address': 'Linking Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Juhu Tara Road',
#         'distance': 467,
#         'formattedAddress': ['Linking Road (Juhu Tara Road)',
#          'Mumbai 400021',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08426330163113,
#           'lng': 72.83428072929382}],
#         'lat': 19.08426330163113,
#         'lng': 72.83428072929382,
#         'postalCode': '400021',
#         'state': 'Mahārāshtra'},
#        'name': 'Airplane Garden',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5194ca0e498ebdad458414b6-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'primary': True,
#          'shortName': 'Market'}],
#        'id': '5194ca0e498ebdad458414b6',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'distance': 317,
#         'formattedAddress': ['India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08192580720032,
#           'lng': 72.84005771503011}],
#         'lat': 19.08192580720032,
#         'lng': 72.84005771503011},
#        'name': 'Santacruz market',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50fe9c0de4b01b26917a4df3-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'primary': True,
#          'shortName': 'Furniture / Home'}],
#        'id': '50fe9c0de4b01b26917a4df3',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'distance': 333,
#         'formattedAddress': ['India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.080685933992427,
#           'lng': 72.84031735395216}],
#         'lat': 19.080685933992427,
#         'lng': 72.84031735395216},
#        'name': 'Hasnabad Market',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e004a42e4cd338f2d447e01-40',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'primary': True,
#          'shortName': 'Apparel'}],
#        'id': '4e004a42e4cd338f2d447e01',
#        'location': {'address': 'S.V. Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 363,
#         'formattedAddress': ['S.V. Road', 'Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.080462322144278,
#           'lng': 72.84057100092934}],
#         'lat': 19.080462322144278,
#         'lng': 72.84057100092934,
#         'state': 'Mahārāshtra'},
#        'name': 'Aishwarya Design Studio',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50eaccb9e4b036fe5f371dd1-41',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/movingtarget_',
#           'suffix': '.png'},
#          'id': '4f2a23984b9023bd5841ed2c',
#          'name': 'Moving Target',
#          'pluralName': 'Moving Targets',
#          'primary': True,
#          'shortName': 'Moving Target'}],
#        'id': '50eaccb9e4b036fe5f371dd1',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'distance': 486,
#         'formattedAddress': ['India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.081907384263275,
#           'lng': 72.84170785991037}],
#         'lat': 19.081907384263275,
#         'lng': 72.84170785991037},
#        'name': 'Mumbai Local Train: Western Line',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e2a62a214955dbf7acf5b93-42',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'primary': True,
#          'shortName': 'Mall'}],
#        'id': '4e2a62a214955dbf7acf5b93',
#        'location': {'address': 'Acme Mall',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'S. V. Road, Santacruz (West)',
#         'distance': 842,
#         'formattedAddress': ['Acme Mall (S. V. Road, Santacruz (West))',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.088626035231187,
#           'lng': 72.83764776933167}],
#         'lat': 19.088626035231187,
#         'lng': 72.83764776933167,
#         'state': 'Mahārāshtra'},
#        'name': 'Reliance Mart',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e304cb162e1fbac6114050b-43',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4e304cb162e1fbac6114050b',
#        'location': {'address': 'Nehru road, santacruz east',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 682,
#         'formattedAddress': ['Nehru road, santacruz east',
#          'Mumbai 400055',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.080636692222516,
#           'lng': 72.84364070769148}],
#         'lat': 19.080636692222516,
#         'lng': 72.84364070769148,
#         'postalCode': '400055',
#         'state': 'Mahārāshtra'},
#        'name': 'Vihar Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cba6002bac937048d67eb7c-44',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4cba6002bac937048d67eb7c',
#        'location': {'address': 'Below gold gym,santacruz west',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'khiranagar',
#         'distance': 718,
#         'formattedAddress': ['Below gold gym,santacruz west (khiranagar)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.087455106046423,
#           'lng': 72.8381652274124}],
#         'lat': 19.087455106046423,
#         'lng': 72.8381652274124,
#         'state': 'Mahārāshtra'},
#        'name': 'Haribhai Kandohi',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587caf964a520e6a122e3-45',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4b0587caf964a520e6a122e3',
#        'location': {'address': '7th Golibar Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 740,
#         'formattedAddress': ['7th Golibar Road',
#          'Mumbai 400 055',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.076933489250735,
#           'lng': 72.84267717056767}],
#         'lat': 19.076933489250735,
#         'lng': 72.84267717056767,
#         'postalCode': '400 055',
#         'state': 'Mahārāshtra'},
#        'name': 'Hotel Golden Swan',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b0587e5f964a52038a622e3-46',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '4b0587e5f964a52038a622e3',
#        'location': {'address': 'Shri Yogendra Marg',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 779,
#         'formattedAddress': ['Shri Yogendra Marg',
#          'Mumbai 400 055',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08518604651667,
#           'lng': 72.84316800623849}],
#         'lat': 19.08518604651667,
#         'lng': 72.84316800623849,
#         'postalCode': '400 055',
#         'state': 'Mahārāshtra'},
#        'name': 'The Yoga Institute',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c24b808b7b8a593d3e23ce8-47',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd931735',
#          'name': 'Metro Station',
#          'pluralName': 'Metro Stations',
#          'primary': True,
#          'shortName': 'Metro'}],
#        'id': '4c24b808b7b8a593d3e23ce8',
#        'location': {'cc': 'IN',
#         'country': 'India',
#         'distance': 811,
#         'formattedAddress': ['India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.075422995994874,
#           'lng': 72.84204250331179}],
#         'lat': 19.075422995994874,
#         'lng': 72.84204250331179},
#        'name': 'Khar Subway',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dde5e99ae60c6eb2a589109-48',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d104951735',
#          'name': 'Boutique',
#          'pluralName': 'Boutiques',
#          'primary': True,
#          'shortName': 'Boutique'}],
#        'id': '4dde5e99ae60c6eb2a589109',
#        'location': {'address': 'Durga Chambers, Linking Road',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Khar (W)',
#         'distance': 822,
#         'formattedAddress': ['Durga Chambers, Linking Road (Khar (W))',
#          'Mumbai 400052',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.075329676684404,
#           'lng': 72.84208866098622}],
#         'lat': 19.075329676684404,
#         'lng': 72.84208866098622,
#         'postalCode': '400052',
#         'state': 'Mahārāshtra'},
#        'name': 'Guru',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f45277fe4b00215c672bc6c-49',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4f45277fe4b00215c672bc6c',
#        'location': {'address': '7th Road Golibar, Santacruz(East), Mumbai-400055',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Golibar Naka',
#         'distance': 827,
#         'formattedAddress': ['7th Road Golibar, Santacruz(East), Mumbai-400055 (Golibar Naka)',
#          'Mumbai 400055',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.075448148603133,
#           'lng': 72.8423072643259}],
#         'lat': 19.075448148603133,
#         'lng': 72.8423072643259,
#         'postalCode': '400055',
#         'state': 'Mahārāshtra'},
#        'name': 'Food King Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d8f7028c1b1721e625b4646-50',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4d8f7028c1b1721e625b4646',
#        'location': {'address': 'Guru Narayan Rd, Santacruz East',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 896,
#         'formattedAddress': ['Guru Narayan Rd, Santacruz East',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.084517359763858,
#           'lng': 72.84487541435486}],
#         'lat': 19.084517359763858,
#         'lng': 72.84487541435486,
#         'state': 'Mahārāshtra'},
#        'name': 'Galaxy Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c2d79cf4e132d7f7f969cdf-51',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'primary': True,
#          'shortName': 'Cineplex'}],
#        'id': '4c2d79cf4e132d7f7f969cdf',
#        'location': {'address': 'Milan Mall',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'distance': 959,
#         'formattedAddress': ['Milan Mall', 'Mumbai', 'Mahārāshtra', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.08958462015746,
#           'lng': 72.83859796215857}],
#         'lat': 19.08958462015746,
#         'lng': 72.83859796215857,
#         'state': 'Mahārāshtra'},
#        'name': 'Inox',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bea90e1a9900f47019c1640-52',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'primary': True,
#          'shortName': 'Bus Station'}],
#        'id': '4bea90e1a9900f47019c1640',
#        'location': {'address': 'Santacruz (West)',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'country': 'India',
#         'crossStreet': 'Near Milan Subway',
#         'distance': 964,
#         'formattedAddress': ['Santacruz (West) (Near Milan Subway)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.080990600201947,
#           'lng': 72.84634089917427}],
#         'lat': 19.080990600201947,
#         'lng': 72.84634089917427,
#         'state': 'Mahārāshtra'},
#        'name': 'Santacruz Bus Depot',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Bandra - Khar, Mumbai',
#   'headerLocation': 'Bandra - Khar',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 19.090073509000007,
#     'lng': 72.8466781641411},
#    'sw': {'lat': 19.07207349099999, 'lng': 72.8276672358589}},
#   'totalResults': 53}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
from pandas.io.json import json_normalize
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
print(nearby_venues.shape)
nearby_venues.head(15)
# Out:
# (53, 4)
#                                  name            categories        lat  \
# 0                     Gokul Icecreams        Ice Cream Shop  19.081607
# 1                          Sandwizzaa        Sandwich Place  19.080700
# 2                             Seasons         Women's Store  19.080887
# 3                      Society Stores     Convenience Store  19.084338
# 4                         Ram & Shyam            Food Truck  19.078220
# 5                   Being Human Store        Clothing Store  19.079782
# 6                      Three Wise Men                   Pub  19.084432
# 7                     Atrang Fashions         Jewelry Store  19.082495
# 8                                Joss   Japanese Restaurant  19.085574
# 9               Nice Fast Food Corner  Fast Food Restaurant  19.077202
# 10         K 11 Fitness Gym & Academy                   Gym  19.077994
# 11  Starbucks Coffee: A Tata Alliance           Coffee Shop  19.075523
# 12                       Jack & Jones           Men's Store  19.080368
# 13                        Bombay Adda                Lounge  19.075872
# 14       Willingdon Catholic Gymkhana  Gym / Fitness Center  19.075179
#
#           lng
# 0   72.835512
# 1   72.840414
# 2   72.838310
# 3   72.836298
# 4   72.836411
# 5   72.834403
# 6   72.835128
# 7   72.838007
# 8   72.834691
# 9   72.837742
# 10  72.842631
# 11  72.831745
# 12  72.834430
# 13  72.834017
# 14  72.839983

# %%
nearby_venues.categories.unique()
# Out:
# array(['Ice Cream Shop', 'Sandwich Place', "Women's Store",
#        'Convenience Store', 'Food Truck', 'Clothing Store', 'Pub',
#        'Jewelry Store', 'Japanese Restaurant', 'Fast Food Restaurant',
#        'Gym', 'Coffee Shop', "Men's Store", 'Lounge',
#        'Gym / Fitness Center', 'French Restaurant',
#        'Furniture / Home Store', 'Boutique', 'Steakhouse', 'Snack Place',
#        'Thai Restaurant', 'Indian Restaurant', 'Juice Bar', 'Music Venue',
#        'Chinese Restaurant', 'Train Station', 'Pizza Place', 'Café',
#        'Bakery', 'Park', 'Market', 'Moving Target', 'Shopping Mall',
#        'Hotel', 'Yoga Studio', 'Metro Station', 'Multiplex',
#        'Bus Station'], dtype=object)
